# %%
pip install lmfit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install asteval
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# <examples/doc_model_gaussian.py>
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt, log
import scipy.stats as st
from scipy.optimize import curve_fit
import pandas as pd
from lmfit import Model
import asteval

data= pd.read_csv('data.csv', thousands=',')
data.columns = {'Year', 'Population'}
x = data['Year']#.values.reshape(-1,1)
y = data['Population']#.values.reshape(-1,1)



gmodel = ExpressionModel('sqrt(x-1900)')
result = gmodel.eval(x=x)

# %%
fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(title='Singapore Population Data')
ax1.plot(y,x,'o')
#ax1.plot(result,x , 'r-', label='best fit')



# <end examples/doc_model_gaussian.py>
